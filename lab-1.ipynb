# %% [markdown]
# # Prelab #1

# %%
'''
Import and run test functions for jlab module.

No output is produced if all tests pass.
'''

import jlab as jl

jl.test_resistor_functions()
jl.test_capacitor_functions()

# %% [markdown]
# ![Circuit Image][def]
#
# [def]: Images/Prelab1-circuit.png
#
# $$ I = V/R = 10 V / 10 \cdot 10^3 \Omega = 10^{-3} A = 10 mA$$
#
# $$ P = (\Delta V)^2 / R = 10 V ^2 / 10 \cdot 10^3 \Omega = 100 mW $$
#
# ![Circuit Measured Values](Images/Prelab1-circuitvalues.png)
#
# The calculated and measured values match!
